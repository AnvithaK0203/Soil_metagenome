# %% [markdown]
# # Baseline Model Gate
#
# This notebook documents the preprocessing and modeling gate.

# %%
# !python scripts/preprocess.py
# !python scripts/train_baseline.py
# !python scripts/evaluate.py
